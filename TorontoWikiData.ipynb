# %% [markdown]
# <h3>Week 3 Assignment on Segmenting and Clustering</h3>

# %%
import pandas as pd
import numpy as np
from bs4 import BeautifulSoup
import requests
import matplotlib.pyplot as plt
import csv
import urllib
import re
# %matplotlib inline

# %%
#Extract table from wiki
source = requests.get('https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M').text
soup = BeautifulSoup(source,'lxml')

tabs = soup.find_all('table', class_='wikitable sortable')
#print(tabs)
#print(tabs.prettify())

type(tabs)
# Out:
# bs4.element.ResultSet

# %% [markdown]
# <h3> Extract Data from Wikipedia</h3>

# %%
tabs = tabs[0]
type(tabs)
# Out:
# bs4.element.Tag

# %%
#EXTRACT DATA AND WRITE TO CSV FILE
with open('wikidata.csv', 'a') as csvFile:
    for row in tabs.find_all('tr'):
        writer = csv.writer(csvFile)
        writer.writerow(row)

# %%
#Convert csv to dataframe
datadf = pd.read_csv('wikidata.csv')
#datadf = datadf.drop(['.1', '.2'], axis=1)

# %% [markdown]
# <h3>Transform Data to Dataframe</h3>

# %%
datadf.head(10)
# Out:
#    \n <th>Postcode</th> \n.1  \
# 0  \n      <td>M1A</td>   \n
# 1  \n      <td>M2A</td>   \n
# 2  \n      <td>M3A</td>   \n
# 3  \n      <td>M4A</td>   \n
# 4  \n      <td>M5A</td>   \n
# 5  \n      <td>M5A</td>   \n
# 6  \n      <td>M6A</td>   \n
# 7  \n      <td>M6A</td>   \n
# 8  \n      <td>M7A</td>   \n
# 9  \n      <td>M8A</td>   \n
#
#                                     <th>Borough</th> \n.2  \
# 0                              <td>Not assigned</td>   \n
# 1                              <td>Not assigned</td>   \n
# 2  <td><a href="/wiki/North_York" title="North Yo...   \n
# 3  <td><a href="/wiki/North_York" title="North Yo...   \n
# 4  <td><a href="/wiki/Downtown_Toronto" title="Do...   \n
# 5  <td><a href="/wiki/Downtown_Toronto" title="Do...   \n
# 6  <td><a href="/wiki/North_York" title="North Yo...   \n
# 7  <td><a href="/wiki/North_York" title="North Yo...   \n
# 8  <td><a href="/wiki/Queen%27s_Park_(Toronto)" t...   \n
# 9                              <td>Not assigned</td>   \n
#
#                             <th>Neighbourhood\n</th>
# 0                            <td>Not assigned\n</td>
# 1                            <td>Not assigned\n</td>
# 2  <td><a href="/wiki/Parkwoods" title="Parkwoods...
# 3  <td><a href="/wiki/Victoria_Village" title="Vi...
# 4  <td><a href="/wiki/Harbourfront_(Toronto)" tit...
# 5  <td><a href="/wiki/Regent_Park" title="Regent ...
# 6  <td><a href="/wiki/Lawrence_Heights" title="La...
# 7  <td><a href="/wiki/Lawrence_Manor" title="Lawr...
# 8                            <td>Not assigned\n</td>
# 9                            <td>Not assigned\n</td>

# %%
#Replace columns with column headers
datadf.columns = ["one","Postcode","two", "Borough","three", "Neighbourhood"]

# %%
#Strip unwanted characters out of Postcode
datadf['Postcode'] = datadf['Postcode'].map(lambda x: x.lstrip('<td>').rstrip('</td>'))
datadf.head()
# Out:
#   one Postcode two                                            Borough three  \
# 0  \n      M1A  \n                              <td>Not assigned</td>    \n
# 1  \n      M2A  \n                              <td>Not assigned</td>    \n
# 2  \n      M3A  \n  <td><a href="/wiki/North_York" title="North Yo...    \n
# 3  \n      M4A  \n  <td><a href="/wiki/North_York" title="North Yo...    \n
# 4  \n      M5A  \n  <td><a href="/wiki/Downtown_Toronto" title="Do...    \n
#
#                                        Neighbourhood
# 0                            <td>Not assigned\n</td>
# 1                            <td>Not assigned\n</td>
# 2  <td><a href="/wiki/Parkwoods" title="Parkwoods...
# 3  <td><a href="/wiki/Victoria_Village" title="Vi...
# 4  <td><a href="/wiki/Harbourfront_(Toronto)" tit...

# %%
#Drop unwanted columns
datadf = datadf.drop(["one","two","three"], axis=1)

# %%
#"Clean column using Regular Expressions"
datadf['Borough'] = datadf['Borough'].str.extract(r'title="(.*?)">')
datadf.head()
# Out:
#   Postcode           Borough  \
# 0      M1A               NaN
# 1      M2A               NaN
# 2      M3A        North York
# 3      M4A        North York
# 4      M5A  Downtown Toronto
#
#                                        Neighbourhood
# 0                            <td>Not assigned\n</td>
# 1                            <td>Not assigned\n</td>
# 2  <td><a href="/wiki/Parkwoods" title="Parkwoods...
# 3  <td><a href="/wiki/Victoria_Village" title="Vi...
# 4  <td><a href="/wiki/Harbourfront_(Toronto)" tit...

# %%
#"Clean column using Regular Expressions"
datadf['Neighbourhood'] = datadf['Neighbourhood'].str.extract(r'title="(.*?)">')
datadf.head(10)
# Out:
#   Postcode                 Borough           Neighbourhood
# 0      M1A                     NaN                     NaN
# 1      M2A                     NaN                     NaN
# 2      M3A              North York               Parkwoods
# 3      M4A              North York        Victoria Village
# 4      M5A        Downtown Toronto  Harbourfront (Toronto)
# 5      M5A        Downtown Toronto             Regent Park
# 6      M6A              North York        Lawrence Heights
# 7      M6A              North York          Lawrence Manor
# 8      M7A  Queen's Park (Toronto)                     NaN
# 9      M8A                     NaN                     NaN

# %%
#Remove null data from Borough Column
datadf = datadf[pd.notnull(datadf['Borough'])]

# %%
datadf.head()
# Out:
#   Postcode           Borough           Neighbourhood
# 2      M3A        North York               Parkwoods
# 3      M4A        North York        Victoria Village
# 4      M5A  Downtown Toronto  Harbourfront (Toronto)
# 5      M5A  Downtown Toronto             Regent Park
# 6      M6A        North York        Lawrence Heights

# %%
datadf.groupby(['Postcode'])

# %%
#Replace Null Neighbourhood data with Borough
datadf.loc[(pd.isnull(datadf.Neighbourhood), 'Neighbourhood')] = datadf.Borough
datadf.head(10)
# Out:
#    Postcode                 Borough           Neighbourhood
# 2       M3A              North York               Parkwoods
# 3       M4A              North York        Victoria Village
# 4       M5A        Downtown Toronto  Harbourfront (Toronto)
# 5       M5A        Downtown Toronto             Regent Park
# 6       M6A              North York        Lawrence Heights
# 7       M6A              North York          Lawrence Manor
# 8       M7A  Queen's Park (Toronto)  Queen's Park (Toronto)
# 10      M9A               Etobicoke        Islington Avenue
# 11      M1B    Scarborough, Toronto          Rouge, Toronto
# 12      M1B    Scarborough, Toronto        Malvern, Toronto

# %%
# Out:
#      index Postcode                 Borough              Neighbourhood
# 0        2      M3A              North York                  Parkwoods
# 1        3      M4A              North York           Victoria Village
# 2        4      M5A        Downtown Toronto     Harbourfront (Toronto)
# 3        5      M5A        Downtown Toronto                Regent Park
# 4        6      M6A              North York           Lawrence Heights
# 5        7      M6A              North York             Lawrence Manor
# 6        8      M7A  Queen's Park (Toronto)     Queen's Park (Toronto)
# 7       10      M9A               Etobicoke           Islington Avenue
# 8       11      M1B    Scarborough, Toronto             Rouge, Toronto
# 9       12      M1B    Scarborough, Toronto           Malvern, Toronto
# 10      14      M3B              North York                 North York
# 11      15      M4B               East York           Woodbine Gardens
# 12      16      M4B               East York              Parkview Hill
# 13      17      M5B        Downtown Toronto           Downtown Toronto
# 14      18      M5B        Downtown Toronto           Downtown Toronto
# 15      19      M6B              North York                 North York
# 16      22      M9B               Etobicoke                  Etobicoke
# 17      23      M9B               Etobicoke         Islington, Toronto
# 18      24      M9B               Etobicoke                  Etobicoke
# 19      25      M9B               Etobicoke           Princess Gardens
# 20      26      M9B               Etobicoke            West Deane Park
# 21      27      M1C    Scarborough, Toronto   Highland Creek (Toronto)
# 22      28      M1C    Scarborough, Toronto                 Rouge Hill
# 23      29      M1C    Scarborough, Toronto        Port Union, Toronto
# 24      31      M3C              North York            Flemingdon Park
# 25      32      M3C              North York                 North York
# 26      33      M4C               East York           Woodbine Heights
# 27      34      M5C        Downtown Toronto             St. James Town
# 28      38      M9C               Etobicoke                  Etobicoke
# 29      39      M9C               Etobicoke                  Etobicoke
# ..     ...      ...                     ...                        ...
# 178    235      M9V               Etobicoke                Thistletown
# 179    236      M1W    Scarborough, Toronto       Scarborough, Toronto
# 180    239      M4W        Downtown Toronto          Rosedale, Toronto
# 181    240      M5W        Downtown Toronto           Downtown Toronto
# 182    243      M8W               Etobicoke         Alderwood, Toronto
# 183    244      M8W               Etobicoke       Long Branch, Toronto
# 184    245      M9W               Etobicoke                  Etobicoke
# 185    246      M1X    Scarborough, Toronto                Upper Rouge
# 186    249      M4X        Downtown Toronto       Cabbagetown, Toronto
# 187    250      M4X        Downtown Toronto             St. James Town
# 188    251      M5X        Downtown Toronto       First Canadian Place
# 189    252      M5X        Downtown Toronto           Underground city
# 190    255      M8X               Etobicoke               The Kingsway
# 191    256      M8X               Etobicoke                  Etobicoke
# 192    257      M8X               Etobicoke                  Etobicoke
# 193    262      M4Y        Downtown Toronto       Church and Wellesley
# 194    265      M7Y            East Toronto               East Toronto
# 195    266      M8Y               Etobicoke                 Humber Bay
# 196    267      M8Y               Etobicoke                  Etobicoke
# 197    268      M8Y               Etobicoke                  Etobicoke
# 198    269      M8Y               Etobicoke                     Mimico
# 199    270      M8Y               Etobicoke          Old Mill, Toronto
# 200    271      M8Y               Etobicoke              The Queensway
# 201    272      M8Y               Etobicoke  Fairmont Royal York Hotel
# 202    273      M8Y               Etobicoke                   Sunnylea
# 203    282      M8Z               Etobicoke                  Etobicoke
# 204    283      M8Z               Etobicoke                     Mimico
# 205    284      M8Z               Etobicoke              The Queensway
# 206    285      M8Z               Etobicoke                  Etobicoke
# 207    286      M8Z               Etobicoke                  Etobicoke
#
# [208 rows x 4 columns]
